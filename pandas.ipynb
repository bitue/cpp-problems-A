# %% [markdown]
# <a href="https://colab.research.google.com/github/bitue/cpp-problems-A/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/heart_disease_uci.csv")
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.head(100)
# Out:
#      id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..  ...  ...     ...        ...              ...       ...    ...    ...
# 95   96   52    Male  Cleveland     asymptomatic     128.0  255.0  False
# 96   97   59    Male  Cleveland     asymptomatic     110.0  239.0  False
# 97   98   60  Female  Cleveland     asymptomatic     150.0  258.0  False
# 98   99   52    Male  Cleveland  atypical angina     134.0  201.0  False
# 99  100   48    Male  Cleveland     asymptomatic     122.0  222.0  False
#
#            restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df.shape
# Out:
# (920, 16)

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df["age"].min()
# Out:
# 28

# %%
df['age'].median()
# Out:
# 54.0

# %%
df[["age", "trestbps"]].mode()
# Out:
#    age  trestbps
# 0   54     120.0

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.shape
# Out:
# (920, 16)

# %% [markdown]
# describe method use to generate report of all data

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %% [markdown]
# mode means which value frequently place

# %%
df["age"].mode()
# Out:
# 0    54
# Name: age, dtype: int64

# %%
age = df['age']
age
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 915    54
# 916    62
# 917    55
# 918    58
# 919    62
# Name: age, Length: 920, dtype: int64

# %% [markdown]
# by knowing the shape means matrixs order here age is one Dimentional array

# %%
age.shape
# Out:
# (920,)

# %% [markdown]
# unique basically use for the catagorial data records which means what type of catagorical data use here

# %%
df["slope"].unique()
# Out:
# array(['downsloping', 'flat', 'upsloping', nan], dtype=object)

# %% [markdown]
# catagorical data count by this following method

# %%
df["slope"].value_counts()
# Out:
# slope
# flat           345
# upsloping      203
# downsloping     63
# Name: count, dtype: int64

# %%
df["age"].unique()
# Out:
# array([63, 67, 37, 41, 56, 62, 57, 53, 44, 52, 48, 54, 49, 64, 58, 60, 50,
#        66, 43, 40, 69, 59, 42, 55, 61, 65, 71, 51, 46, 45, 39, 68, 47, 34,
#        35, 29, 70, 77, 38, 74, 76, 28, 30, 31, 32, 33, 36, 72, 73, 75])

# %%
df.describe(include="all")
# Out:
#                 id         age   sex    dataset            cp    trestbps  \
# count   920.000000  920.000000   920        920           920  861.000000
# unique         NaN         NaN     2          4             4         NaN
# top            NaN         NaN  Male  Cleveland  asymptomatic         NaN
# freq           NaN         NaN   726        304           496         NaN
# mean    460.500000   53.510870   NaN        NaN           NaN  132.132404
# std     265.725422    9.424685   NaN        NaN           NaN   19.066070
# min       1.000000   28.000000   NaN        NaN           NaN    0.000000
# 25%     230.750000   47.000000   NaN        NaN           NaN  120.000000
# 50%     460.500000   54.000000   NaN        NaN           NaN  130.000000
# 75%     690.250000   60.000000   NaN        NaN           NaN  140.000000
# max     920.000000   77.000000   NaN        NaN           NaN  200.000000
#
#               chol    fbs restecg      thalch  exang     oldpeak slope  \
# ...

# %% [markdown]
# here it generate the report only for catagorical data

# %%
df.describe(include="object")
# Out:
#          sex    dataset            cp    fbs restecg  exang slope    thal
# count    920        920           920    830     918    865   611     434
# unique     2          4             4      2       3      2     3       3
# top     Male  Cleveland  asymptomatic  False  normal  False  flat  normal
# freq     726        304           496    692     551    528   345     196

# %%
df["thal"].unique()
# Out:
# array(['fixed defect', 'normal', 'reversable defect', nan], dtype=object)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df["dataset"].value_counts()
# Out:
# dataset
# Cleveland        304
# Hungary          293
# VA Long Beach    200
# Switzerland      123
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      726
# Female    194
# Name: count, dtype: int64

# %%
df["age"].value_counts()
# Out:
# age
# 54    51
# 58    43
# 55    41
# 56    38
# 57    38
# 52    36
# 62    35
# 51    35
# 59    35
# 53    33
# 60    32
# 61    31
# 48    31
# 63    30
# 50    25
# 41    24
# 46    24
# 43    24
# 64    22
# 49    22
# 65    21
# 44    19
# 47    19
# 45    18
# 42    18
# 38    16
# 67    15
# 39    15
# 69    13
# 40    13
# 66    13
# 35    11
# 37    11
# 68    10
# 34     7
# 70     7
# 74     7
# 36     6
# 32     5
# 71     5
# 72     4
# 29     3
# 75     3
# 31     2
# 33     2
# 76     2
# 77     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64

# %%
age_count = df["age"].value_counts()
age_count
# Out:
# age
# 54    51
# 58    43
# 55    41
# 56    38
# 57    38
# 52    36
# 62    35
# 51    35
# 59    35
# 53    33
# 60    32
# 61    31
# 48    31
# 63    30
# 50    25
# 41    24
# 46    24
# 43    24
# 64    22
# 49    22
# 65    21
# 44    19
# 47    19
# 45    18
# 42    18
# 38    16
# 67    15
# 39    15
# 69    13
# 40    13
# 66    13
# 35    11
# 37    11
# 68    10
# 34     7
# 70     7
# 74     7
# 36     6
# 32     5
# 71     5
# 72     4
# 29     3
# 75     3
# 31     2
# 33     2
# 76     2
# 77     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64

# %%
age_count.shape
# Out:
# (50,)

# %% [markdown]
# just here for example

# %%
co =0
for i in age_count :
  co = co + i

co
# Out:
# 920

# %%
print("i love ML")
# Out:
# i love ML

# %%
info_dict = {
    "name": "ashikul islam",
    "nick_name": "ashik",
    "age": 24,
    "gender": "male",
    "country": "Bangladesh",
    "language": "python",

}

# %%
info_dict
# Out:
# {'name': 'ashikul islam',
#  'nick_name': 'ashik',
#  'age': 24,
#  'gender': 'male',
#  'country': 'Bangladesh',
#  'language': 'python'}

# %%
type(info_dict)
# Out:
# dict

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
ser = pd.Series(np.random.randn(6), index = ["name", "nick_name", "age", "gender", "country", "language"])

# %%
ser
# Out:
# name         0.069690
# nick_name    0.175755
# age          0.803199
# gender      -1.185833
# country      1.656131
# language    -1.364206
# dtype: float64

# %%
df.sex
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 915    Female
# 916      Male
# 917      Male
# 918      Male
# 919      Male
# Name: sex, Length: 920, dtype: object

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# row wise information

# %%
df.loc[20]
# Out:
# id                      21
# age                     64
# sex                   Male
# dataset          Cleveland
# cp          typical angina
# trestbps             110.0
# chol                 211.0
# fbs                  False
# restecg     lv hypertrophy
# thalch               144.0
# exang                 True
# oldpeak                1.8
# slope                 flat
# ca                     0.0
# thal                normal
# num                      0
# Name: 20, dtype: object

# %%
df.loc[[20, 25]]
# Out:
#     id  age     sex    dataset              cp  trestbps   chol    fbs  \
# 20  21   64    Male  Cleveland  typical angina     110.0  211.0  False
# 25  26   50  Female  Cleveland     non-anginal     120.0  219.0  False
#
#            restecg  thalch  exang  oldpeak slope   ca    thal  num
# 20  lv hypertrophy   144.0   True      1.8  flat  0.0  normal    0
# 25          normal   158.0  False      1.6  flat  0.0  normal    0

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.iloc[20:25]
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 20  21   64    Male  Cleveland   typical angina     110.0  211.0  False
# 21  22   58  Female  Cleveland   typical angina     150.0  283.0   True
# 22  23   58    Male  Cleveland  atypical angina     120.0  284.0  False
# 23  24   58    Male  Cleveland      non-anginal     132.0  224.0  False
# 24  25   60    Male  Cleveland     asymptomatic     130.0  206.0  False
#
#            restecg  thalch  exang  oldpeak      slope   ca               thal  \
# 20  lv hypertrophy   144.0   True      1.8       flat  0.0             normal
# 21  lv hypertrophy   162.0  False      1.0  upsloping  0.0             normal
# 22  lv hypertrophy   160.0  False      1.8       flat  0.0             normal
# 23  lv hypertrophy   173.0  False      3.2  upsloping  2.0  reversable defect
# 24  lv hypertrophy   132.0   True      2.4       flat  2.0  reversable defect
#
#     num
# 20    0
# 21    0
# 22    1
# 23    3
# 24    4

# %% [markdown]
# df.iloc[start row : end row , start col : end col]

# %%
df.iloc[20 : 25]
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 20  21   64    Male  Cleveland   typical angina     110.0  211.0  False
# 21  22   58  Female  Cleveland   typical angina     150.0  283.0   True
# 22  23   58    Male  Cleveland  atypical angina     120.0  284.0  False
# 23  24   58    Male  Cleveland      non-anginal     132.0  224.0  False
# 24  25   60    Male  Cleveland     asymptomatic     130.0  206.0  False
#
#            restecg  thalch  exang  oldpeak      slope   ca               thal  \
# 20  lv hypertrophy   144.0   True      1.8       flat  0.0             normal
# 21  lv hypertrophy   162.0  False      1.0  upsloping  0.0             normal
# 22  lv hypertrophy   160.0  False      1.8       flat  0.0             normal
# 23  lv hypertrophy   173.0  False      3.2  upsloping  2.0  reversable defect
# 24  lv hypertrophy   132.0   True      2.4       flat  2.0  reversable defect
#
#     num
# 20    0
# 21    0
# 22    1
# 23    3
# 24    4

# %%
x=df.iloc[20 : 25 : 2, 0 : 5 : 2]
x
# Out:
#     id   sex               cp
# 20  21  Male   typical angina
# 22  23  Male  atypical angina
# 24  25  Male     asymptomatic

# %% [markdown]
# df.iloc[start row : end row : gap , start col : end col : gap]

# %%
df.loc[23 : 27]
# Out:
#     id  age     sex    dataset              cp  trestbps   chol    fbs  \
# 23  24   58    Male  Cleveland     non-anginal     132.0  224.0  False
# 24  25   60    Male  Cleveland    asymptomatic     130.0  206.0  False
# 25  26   50  Female  Cleveland     non-anginal     120.0  219.0  False
# 26  27   58  Female  Cleveland     non-anginal     120.0  340.0  False
# 27  28   66  Female  Cleveland  typical angina     150.0  226.0  False
#
#            restecg  thalch  exang  oldpeak        slope   ca  \
# 23  lv hypertrophy   173.0  False      3.2    upsloping  2.0
# 24  lv hypertrophy   132.0   True      2.4         flat  2.0
# 25          normal   158.0  False      1.6         flat  0.0
# 26          normal   172.0  False      0.0    upsloping  0.0
# 27          normal   114.0  False      2.6  downsloping  0.0
#
#                  thal  num
# 23  reversable defect    3
# 24  reversable defect    4
# 25             normal    0
# 26             normal    0
# 27             normal    0

# %%
df.loc[23 : 27, "age" : "sex"]
# Out:
#     age     sex
# 23   58    Male
# 24   60    Male
# 25   50  Female
# 26   58  Female
# 27   66  Female

# %%
df.loc[23 : 27, "age" : "ca"]
# Out:
#     age     sex    dataset              cp  trestbps   chol    fbs  \
# 23   58    Male  Cleveland     non-anginal     132.0  224.0  False
# 24   60    Male  Cleveland    asymptomatic     130.0  206.0  False
# 25   50  Female  Cleveland     non-anginal     120.0  219.0  False
# 26   58  Female  Cleveland     non-anginal     120.0  340.0  False
# 27   66  Female  Cleveland  typical angina     150.0  226.0  False
#
#            restecg  thalch  exang  oldpeak        slope   ca
# 23  lv hypertrophy   173.0  False      3.2    upsloping  2.0
# 24  lv hypertrophy   132.0   True      2.4         flat  2.0
# 25          normal   158.0  False      1.6         flat  0.0
# 26          normal   172.0  False      0.0    upsloping  0.0
# 27          normal   114.0  False      2.6  downsloping  0.0

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.loc[0 : 500 , "age" : "ca"]
# Out:
#      age     sex    dataset               cp  trestbps   chol    fbs  \
# 0     63    Male  Cleveland   typical angina     145.0  233.0   True
# 1     67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2     67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3     37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4     41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...     ...        ...              ...       ...    ...    ...
# 496   37    Male    Hungary     asymptomatic     140.0  207.0  False
# 497   38    Male    Hungary     asymptomatic     110.0  196.0  False
# 498   38    Male    Hungary     asymptomatic     120.0  282.0  False
# 499   38    Male    Hungary     asymptomatic      92.0  117.0  False
# 500   40    Male    Hungary     asymptomatic     120.0  466.0    NaN
#
#             restecg  thalch  exang  oldpeak        slope   ca
# 0    lv hypertrophy   150.0  False      2.3  downsloping  0.0
# ...

# %%
df["dataset"].apply(len)
# Out:
# 0       9
# 1       9
# 2       9
# 3       9
# 4       9
#        ..
# 915    13
# 916    13
# 917    13
# 918    13
# 919    13
# Name: dataset, Length: 920, dtype: int64

# %%
def custom_fun(x):
  return x.upper()

# %%
df["dataset"].apply(custom_fun)
# Out:
# 0          CLEVELAND
# 1          CLEVELAND
# 2          CLEVELAND
# 3          CLEVELAND
# 4          CLEVELAND
#            ...
# 915    VA LONG BEACH
# 916    VA LONG BEACH
# 917    VA LONG BEACH
# 918    VA LONG BEACH
# 919    VA LONG BEACH
# Name: dataset, Length: 920, dtype: object

# %%
def traverse_all (x):
  return type(x)

# %%
df.apply(traverse_all)
# Out:
# id          <class 'pandas.core.series.Series'>
# age         <class 'pandas.core.series.Series'>
# sex         <class 'pandas.core.series.Series'>
# dataset     <class 'pandas.core.series.Series'>
# cp          <class 'pandas.core.series.Series'>
# trestbps    <class 'pandas.core.series.Series'>
# chol        <class 'pandas.core.series.Series'>
# fbs         <class 'pandas.core.series.Series'>
# restecg     <class 'pandas.core.series.Series'>
# thalch      <class 'pandas.core.series.Series'>
# exang       <class 'pandas.core.series.Series'>
# oldpeak     <class 'pandas.core.series.Series'>
# slope       <class 'pandas.core.series.Series'>
# ca          <class 'pandas.core.series.Series'>
# thal        <class 'pandas.core.series.Series'>
# num         <class 'pandas.core.series.Series'>
# dtype: object

# %%
def tra (x) :
  return len(x)

# %% [markdown]
# replace function is very powerful i hope
#
#
# df.replace({"the value need to change ": "the value is to need ", "the value need to change ": "the value is to need ", .....})

# %%
df["sex"].replace({"Male" : 1, "Female" : 2})
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 915    2
# 916    1
# 917    1
# 918    1
# 919    1
# Name: sex, Length: 920, dtype: int64

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
def age_res (x):
  if x < 20 :
    return "young"
  elif x < 40 :
    return "middle"
  else :
    return "old"

# %%
type(age_cat)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
age_cat.shape
# Out:
# (920,)

# %%
age_cat_np = age_cat.to_numpy()
age_cat_np
# Out:
# array(['old', 'old', 'old', 'middle', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'middle', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'old', 'middle', 'old', 'old', 'old', 'old', 'old', 'old',
#        'old', 'middle', 'old', 'old', 'old', 'old', 'old', 'old', 'old',
# ...

# %%
age_cat_np.shape
# Out:
# (920,)

# %%
df.loc(df['sex']== "Male")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-94835c5345f4> in <cell line: 1>()
# ----> 1 df.loc(df['sex']== "Male")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     720
#     721         if axis is not None:
# --> 722             axis_int_none = self.obj._get_axis_number(axis)
#     723         else:
#     724             axis_int_none = axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     550     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     551         try:
# --> 552             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     553         except KeyError:
#     554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# df.loc[filter]
# filter = df["sex"] == "Male"

# %%
df.loc[df['sex']== "Male"]
# Out:
#       id  age   sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63  Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67  Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67  Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37  Male      Cleveland      non-anginal     130.0  250.0  False
# 5      6   56  Male      Cleveland  atypical angina     120.0  236.0  False
# ..   ...  ...   ...            ...              ...       ...    ...    ...
# 914  915   46  Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 916  917   62  Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55  Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58  Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62  Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
fil = df["dataset"] == "Cleveland"
pat = df.loc[fil]
pat
# Out:
#       id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...        ...              ...       ...    ...    ...
# 299  300   68    Male  Cleveland     asymptomatic     144.0  193.0   True
# 300  301   57    Male  Cleveland     asymptomatic     130.0  131.0  False
# 301  302   57  Female  Cleveland  atypical angina     130.0  236.0  False
# 302  303   38    Male  Cleveland      non-anginal     138.0  175.0  False
# 303  304   28    Male  Cleveland  atypical angina     130.0  132.0  False
#
#             restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
com_fil = ((df["dataset"] == "Cleveland") & (df["sex"] == "Male") & (df["age"] > 50) )
com_pat = df.loc[com_fil]
com_pat
# Out:
#       id  age   sex    dataset               cp  trestbps   chol    fbs  \
# 0      1   63  Male  Cleveland   typical angina     145.0  233.0   True
# 1      2   67  Male  Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67  Male  Cleveland     asymptomatic     120.0  229.0  False
# 5      6   56  Male  Cleveland  atypical angina     120.0  236.0  False
# 8      9   63  Male  Cleveland     asymptomatic     130.0  254.0  False
# ..   ...  ...   ...        ...              ...       ...    ...    ...
# 290  291   67  Male  Cleveland      non-anginal     152.0  212.0  False
# 293  294   63  Male  Cleveland     asymptomatic     140.0  187.0  False
# 296  297   59  Male  Cleveland     asymptomatic     164.0  176.0   True
# 299  300   68  Male  Cleveland     asymptomatic     144.0  193.0   True
# 300  301   57  Male  Cleveland     asymptomatic     130.0  131.0  False
#
#             restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.loc[0 , "sex"] = "Male"

# %%
df
# Out:
#       id   age     sex        dataset               cp  trestbps   chol  \
# 0      1  Male    Male      Cleveland   typical angina     145.0  233.0
# 1      2    67    Male      Cleveland     asymptomatic     160.0  286.0
# 2      3    67    Male      Cleveland     asymptomatic     120.0  229.0
# 3      4    37    Male      Cleveland      non-anginal     130.0  250.0
# 4      5    41  Female      Cleveland  atypical angina     130.0  204.0
# ..   ...   ...     ...            ...              ...       ...    ...
# 915  916    54  Female  VA Long Beach     asymptomatic     127.0  333.0
# 916  917    62    Male  VA Long Beach   typical angina       NaN  139.0
# 917  918    55    Male  VA Long Beach     asymptomatic     122.0  223.0
# 918  919    58    Male  VA Long Beach     asymptomatic       NaN  385.0
# 919  920    62    Male  VA Long Beach  atypical angina     120.0  254.0
#
#        fbs           restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df
# Out:
#       id   age     sex        dataset               cp  trestbps   chol  \
# 0      1  Male    Male      Cleveland   typical angina     145.0  233.0
# 1      2    67    Male      Cleveland     asymptomatic     160.0  286.0
# 2      3    67    Male      Cleveland     asymptomatic     120.0  229.0
# 3      4    37    Male      Cleveland      non-anginal     130.0  250.0
# 4      5    41  Female      Cleveland  atypical angina     130.0  204.0
# ..   ...   ...     ...            ...              ...       ...    ...
# 915  916    54  Female  VA Long Beach     asymptomatic     127.0  333.0
# 916  917    62    Male  VA Long Beach   typical angina       NaN  139.0
# 917  918    55    Male  VA Long Beach     asymptomatic     122.0  223.0
# 918  919    58    Male  VA Long Beach     asymptomatic       NaN  385.0
# 919  920    62    Male  VA Long Beach  atypical angina     120.0  254.0
#
#        fbs           restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df.rename(columns = {"age" : "Age"}, inplace = True)

# %%
df
# Out:
#       id   Age     sex        dataset               cp  trestbps   chol  \
# 0      1  Male    Male      Cleveland   typical angina     145.0  233.0
# 1      2    67    Male      Cleveland     asymptomatic     160.0  286.0
# 2      3    67    Male      Cleveland     asymptomatic     120.0  229.0
# 3      4    37    Male      Cleveland      non-anginal     130.0  250.0
# 4      5    41  Female      Cleveland  atypical angina     130.0  204.0
# ..   ...   ...     ...            ...              ...       ...    ...
# 915  916    54  Female  VA Long Beach     asymptomatic     127.0  333.0
# 916  917    62    Male  VA Long Beach   typical angina       NaN  139.0
# 917  918    55    Male  VA Long Beach     asymptomatic     122.0  223.0
# 918  919    58    Male  VA Long Beach     asymptomatic       NaN  385.0
# 919  920    62    Male  VA Long Beach  atypical angina     120.0  254.0
#
#        fbs           restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
df.columns
# Out:
# Index([      'id',      'Age',      'sex',  'dataset',       'cp', 'trestbps',
#            'chol',      'fbs',  'restecg',   'thalch',    'exang',  'oldpeak',
#           'slope',       'ca',     'thal',      'num',          2],
#       dtype='object')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
co =0
coo =0

# %%
import math

def float_to_int (x):
  if  math.isnan(x) :

    return 0
  else :

    return int(x)

# %%
df['ca'].value_counts()
# Out:
# ca
# 0.0    181
# 1.0     67
# 2.0     41
# 3.0     20
# Name: count, dtype: int64

# %%
df['ca'].shape
# Out:
# (920,)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
dff = pd.read_csv("/content/drive/MyDrive/property_listing_data_in_Bangladesh.csv")
dff
# Out:
#                                                   title beds bath        area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1     Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2     Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4     Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# ...                                                 ...  ...  ...         ...
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   object
#  2   bath         7557 non-null   object
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: object(11)
# memory usage: 649.6+ KB

# %%
def str_to_int (x):
  y, z = x.split(" ")

  return float(y)*1000

# %%
dff['price']=dff['price'].apply(str_to_int)
dff['price']
# Out:
# 0       50000.0
# 1       30000.0
# 2       30000.0
# 3       35000.0
# 4       25000.0
#          ...
# 7552    80000.0
# 7553    19000.0
# 7554    22000.0
# 7555     1750.0
# 7556    90000.0
# Name: price, Length: 7557, dtype: float64

# %%
arr["price"]
# Out:
# '50 Thousand'

# %%
y , z= arr["price"].split(" ")
w = int(y)*1000
print(w)
# Out:
# 50000

# %%
dff
# Out:
#                                                   title beds bath        area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1     Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2     Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4     Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# ...                                                 ...  ...  ...         ...
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
# ...

# %%
dff
# Out:
#                                                   title beds bath        area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1     Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2     Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4     Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# ...                                                 ...  ...  ...         ...
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
# ...

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
dp = pd.read_csv("/content/drive/MyDrive/property_listing_data_in_Bangladesh.csv")
dp
# Out:
#                                                   title beds bath        area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1     Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2     Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4     Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# ...                                                 ...  ...  ...         ...
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   object
#  2   bath         7557 non-null   object
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: object(11)
# memory usage: 649.6+ KB

# %%
def str_to_pro (x):
  y, z = x.split(" ")


  return int(y)

# %% [markdown]
# before do aggregatiion we need to do numerical cell instead of catagorical cell data

# %%
dp['beds'] = dp["beds"].apply(str_to_pro)
dp['beds']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 7552    4
# 7553    3
# 7554    2
# 7555    3
# 7556    4
# Name: beds, Length: 7557, dtype: int64

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   object
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 649.6+ KB

# %%
dp['bath'] = dp["bath"].apply(str_to_pro)
dp['bath']
# Out:
# 0       4
# 1       4
# 2       4
# 3       3
# 4       4
#        ..
# 7552    4
# 7553    2
# 7554    2
# 7555    4
# 7556    4
# Name: bath, Length: 7557, dtype: int64

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 649.6+ KB

# %%
arr =[]

# %%
def price_to_num (x):
  y, z = x.split(" ")
  arr.append(z)

  if z== "Lakh" :
    return float(y)*100000
  else  :
    return float(y)*1000
  return float(y)

# %%
from ast import Num
# dic ={}
# def arr(x) :
#   for i in x :
#     if dic.get(i) == None :
#       dic[i] = 1
#     else :
#       dic[i] = dic[i] + 1
#   return dic

def arr(x):
    dic = {}  # Define the dictionary inside the function
    for i in x:
        if dic.get(i) :
            dic[i] = dic.get(i) +1
        else:
            dic[i] = 1
    print(dic)
    return dic

# %%
dp['price'].apply(price_to_num)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-2100c1a2357d> in <cell line: 1>()
# ----> 1 dp['price'].apply(price_to_num)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
#    1288         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %%
arr
# Out:
# ['Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Lakh',
#  'Thousand',
#  'Thousand',
#  'Thousand',
#  'Thousand',
# ...

# %%
zz = arr(arr)
zz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ba5feec3d136> in <cell line: 1>()
# ----> 1 zz = arr(arr)
#       2 zz
#
# TypeError: 'list' object is not callable

# %%
arr
# Out:
# <function __main__.arr(x)>

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 649.6+ KB

# %%
dp
# Out:
#                                                   title  beds  bath  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4
# ...                                                 ...   ...   ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4
#
#             area                              adress       type   purpose  \
# 0     2,200 sqft     Block A, Bashundhara R-A, Dhaka  Apartment  For Rent
# ...

# %%
dp['area'] = dp["area"].apply(str_to_pro)
dp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-900910a09b87> in <cell line: 1>()
# ----> 1 dp['area'] = dp["area"].apply(str_to_pro)
#       2 dp
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4762             args=args,
#    4763             kwargs=kwargs,
# -> 4764         ).apply()
#    4765
#    4766     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1207
#    1208         # self.func is Callable
# -> 1209         return self.apply_standard()
#    1210
#    1211     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1287         #  Categorical (GH51645).
#    1288         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %%
def area_float (x):
  y, z = x.split(" ")
  y = y.replace(",", "")
  return float(y)

# %%
dp['area'] = dp["area"].apply(area_float)

dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   float64
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 649.6+ KB

# %%
price_to_num("1.5 Lac")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4b1bdc10eafa> in <cell line: 1>()
# ----> 1 price_to_num("1.5 Lac")
#
# <ipython-input-43-062f0565bdca> in price_to_num(x)
#       1 def price_to_num (x):
#       2   y, z = x.split(" ")
# ----> 3   arr.append(z)
#       4
#       5   if z== "Lakh" :
#
# AttributeError: 'function' object has no attribute 'append'

# %%
def price_int(x):
  y, z = x.split(" ")
  if z == "Lakh" :
    return float(y)*100000
  else :
    return float(y)*1000

# %%
dp['price'] = dp['price'].apply(price_int)
dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   float64
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 649.6+ KB

# %%
def adress_to_city(x):
  if "Dhaka" in x :
    return "Dhaka"
  elif "Chattogram" in x :
    return "Chattogram"
  else :
    return "pabna"

# %%
dp.drop('city', inplace = True, axis = 1)
dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp['city'] = dp['adress'].apply(adress_to_city)
dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   float64
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   float64
#  11  city         7557 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 708.6+ KB

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   int64
#  2   bath         7557 non-null   int64
#  3   area         7557 non-null   float64
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   float64
#  11  city         7557 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 708.6+ KB

# %%
dp['price'].mean()
# Out:
# 34079.02606854572

# %%
dp['price'].median()
# Out:
# 19000.0

# %%
dp['price'].mode()
# Out:
# 0    15000.0
# Name: price, dtype: float64

# %%
dhaka = dp.loc[dp['city'] == "Dhaka"]
dhaka
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# 5     A nice residential flat of 3400 SQ FT, for ren...     5     5  3400.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 1     Apartment Ready To Rent In South Khulshi, Near...     3     4  1400.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
dp.loc[dp['city'] == "Dhaka"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-624e8ae5c4a5> in <cell line: 1>()
# ----> 1 df.loc[df['city'] == "Dhaka"]
#
# ...

# %%
dp.loc[dp["city"] == "Dhaka"]["price"].mean()
# Out:
# 39909.53488372093

# %%
filter = dp["city"] == "Dhaka"
dp.loc[filter]["price"].mean()
# Out:
# 39909.53488372093

# %%
group_cell = dp.groupby(["city"])
group_cell

# %%
group_cell.get_group("Dhaka")
# Out:
#                                                   title  beds  bath    area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...     3     4  2200.0
# 2     Smartly priced 1950 SQ FT apartment, that you ...     3     4  1950.0
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...     3     3  2000.0
# 4     Strongly Structured This 1650 Sq. ft Apartment...     3     4  1650.0
# 5     A nice residential flat of 3400 SQ FT, for ren...     5     5  3400.0
# ...                                                 ...   ...   ...     ...
# 7552  Picture Yourself, Residing In This Well Constr...     4     4  3600.0
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...     3     2   900.0
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...     2     2  1000.0
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...     3     4  3600.0
# 7556  An Apartment Is Ready For Rent At Baridhara DO...     4     4  2600.0
#
# ...

# %%
group_cell['type'].value_counts()
# Out:
# city        type
# Chattogram  Apartment    2217
#             Duplex          7
#             Building        1
# Dhaka       Apartment    5272
#             Duplex         40
#             Building       20
# Name: count, dtype: int64

# %%
dp["type"].value_counts()
# Out:
# type
# Apartment    7489
# Duplex         47
# Building       21
# Name: count, dtype: int64

# %%
dp["price"].mean()
# Out:
# 34079.02606854572

# %%
group_cell['price'].mean()
# Out:
# city
# Chattogram    20106.768539
# Dhaka         39909.534884
# Name: price, dtype: float64

# %%
group_cell['price'].median()
# Out:
# city
# Chattogram    16000.0
# Dhaka         20000.0
# Name: price, dtype: float64

# %%
group['type'].value_counts()
# Out:
# city        type
# Chattogram  Apartment    2217
#             Building        1
#             Duplex          7
# Dhaka       Apartment    5272
#             Building       20
#             Duplex         40
# Name: count, dtype: int64

# %%
group = dp.groupby(["city", "type"])
group['price'].mean()
# Out:
# city        type
# Chattogram  Apartment     19813.964817
#             Building      70000.000000
#             Duplex       105714.285714
# Dhaka       Apartment     35752.966616
#             Building     696500.000000
#             Duplex       259450.000000
# Name: price, dtype: float64

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
group_by_data = df.groupby(["dataset"])
group_by_data['cp'].apply(lambda x :  sum(x == "asymptomatic"))
# Out:
# dataset
# Cleveland        144
# Hungary          123
# Switzerland       98
# VA Long Beach    131
# Name: cp, dtype: int64

# %%
group['price'].agg(["mean", "median"])
# Out:
#                                mean    median
# city       type
# Chattogram Apartment   19813.964817   16000.0
#            Building    70000.000000   70000.0
#            Duplex     105714.285714   60000.0
# Dhaka      Apartment   35752.966616   20000.0
#            Building   696500.000000  550000.0
#            Duplex     259450.000000  135000.0

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
r = df.loc[0: 10 , : ]
r
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0    1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1    2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2    3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3    4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4    5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5    6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6    7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7    8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8    9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9   10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
# 10  11   57    Male  Cleveland     asymptomatic     140.0  192.0  False
#
#            restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
c = df.loc[910 : ,  : ]
c
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 910  911   51  Female  VA Long Beach     asymptomatic     114.0  258.0   True
# 911  912   62    Male  VA Long Beach     asymptomatic     160.0  254.0   True
# 912  913   53    Male  VA Long Beach     asymptomatic     144.0  300.0   True
# 913  914   62    Male  VA Long Beach     asymptomatic     158.0  170.0  False
# 914  915   46    Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak      slope  ca          thal  \
# ...

# %%
new_df = pd.concat([r, c] , ignore_index=True )
new_df
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df.dropna(axis=0 , how="any")
# Out:
#     id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0    1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1    2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2    3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3    4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4    5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5    6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6    7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7    8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8    9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9   10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
# 10  11   57    Male  Cleveland     asymptomatic     140.0  192.0  False
#
#            restecg  thalch  exang  oldpeak        slope   ca  \
# ...

# %%
new_df
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df.dropna(axis=1 , how="any")
# Out:
#      id  age     sex        dataset               cp   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic  229.0  False
# 3     4   37    Male      Cleveland      non-anginal  250.0  False
# 4     5   41  Female      Cleveland  atypical angina  204.0  False
# 5     6   56    Male      Cleveland  atypical angina  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic  192.0  False
# 11  911   51  Female  VA Long Beach     asymptomatic  258.0   True
# 12  912   62    Male  VA Long Beach     asymptomatic  254.0   True
# ...

# %%
new_df.dropna(axis=0 , how="any", subset=['slope'])
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df.fillna(0)
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df['oldpeak'] = new_df['oldpeak'].fillna(new_df['oldpeak'].mean())
new_df
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df
# Out:
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# 9    10   53    Male      Cleveland     asymptomatic     140.0  203.0   True
# 10   11   57    Male      Cleveland     asymptomatic     140.0  192.0  False
# ...

# %%
new_df.fillna(method="ffill")
# Out:
# <ipython-input-18-ac9d4a7f0d9b>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df.fillna(method="ffill")
#      id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0     1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1     2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2     3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3     4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4     5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5     6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6     7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# 7     8   57  Female      Cleveland     asymptomatic     120.0  354.0  False
# 8     9   63    Male      Cleveland     asymptomatic     130.0  254.0  False
# ...
